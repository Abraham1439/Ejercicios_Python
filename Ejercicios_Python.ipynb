# %% [markdown]
# <a href="https://colab.research.google.com/github/Abraham1439/Ejercicios_Python/blob/main/Ejercicios_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Ejercicio 1
# Escribir un programa que muestre por pantalla la cadena ¡Hola Mundo!.

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %% [markdown]
# #Ejercicio 2
# Escribir un programa que almacene la cadena ¡Hola Mundo! en una variable y luego muestre por pantalla el contenido de la variable.

# %%
saludar = "¡Hola Mundo!"
print(saludar)
# Out:
# ¡Hola Mundo!

# %% [markdown]
# #Ejercicio 3
# Escribir un programa que pregunte el nombre del usuario en la consola y después de que el usuario lo introduzca muestre por pantalla la cadena ¡Hola nombre!, donde nombre es el nombre que el usuario haya introducido.

# %%
nombre = input("Ingrese su nombre: ")
print(f"¡Hola {nombre}!")
# Out:
# Ingrese su nombre: abraham
# ¡Hola abraham!
